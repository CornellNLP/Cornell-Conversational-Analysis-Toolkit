# %% [markdown]
# This example extracts question types from the UK Parliament Question Answer Sessions
# reproducing the asking too much paper (http://www.cs.cornell.edu/~cristian/Asking_too_much.html).
# (due to the non-deterministic nature of clustering, the order of the clusters and some cluster assignments will vary).<br> This version uses precomputed motifs for speed.

# %%
import os
import pkg_resources
import numpy as np

from convokit import Corpus, QuestionTypology, download

# %% [markdown]
# Initializing QuestionTypology Class

# %%
num_clusters = 8

# Get precomputed motifs. data_dir contains the downloaded data. 
# motifs_dir is the specific path within data_dir that contains the precomputed motifs
data_dir = os.path.join(pkg_resources.resource_filename("convokit", ""), 'downloads', 'parliament')
motifs_dir = os.path.join(data_dir, 'parliament-motifs')

#Load the corpus
corpus = Corpus(filename=os.path.join(data_dir, 'parliament-corpus'))

#Extract clusters of the motifs and assign questions to these clusters
questionTypology = QuestionTypology(corpus, data_dir, motifs_dir=motifs_dir, num_dims=25, 
  num_clusters=num_clusters, verbose=False, random_seed=164)
# Out:
# /Users/ishaanjhaveri/anaconda/lib/python3.6/site-packages/sklearn/utils/validation.py:429: DataConversionWarning: Data with input dtype int64 was converted to float64 by the normalize function.
#   warnings.warn(msg, _DataConversionWarning)

# %% [markdown]
# `questionTypology.types_to_data` contains the necessary data that is computed in the step above. Its keys are the indices of the clusters (here 0-7). The values are dictionaries with the following keys:<br>
#     <br>`"motifs"`: the motifs, as a list of tuples of the motif terms
#     <br>`"motif_dists"`: the corresponding distances of each motif from the centroid of the cluster this motif is in
#     <br>`"fragments"`: the answer fragments, as a list of tuples of answer terms
#     <br>`"fragment_dists"`: the corresponding distances of each fragment from the centroid of the cluster this
# fragment is in
#     <br>`"questions"`: the IDs of the questions in this cluster. You can get the corresponding question text by using the
# get_question_text_from_pair_idx(pair_idx) method.
#     <br>`"question_dists"`: the corresponding distances of each question from the centroid of the cluster
# this question is in

# %% [markdown]
# Display Outputs

# %%
questionTypology.display_totals()
print('10 examples for type 1-8:')
for i in range(num_clusters):
    questionTypology.display_motifs_for_type(i, num_egs=10)
    questionTypology.display_answer_fragments_for_type(i, num_egs=10)
    questionTypology.display_questions_for_type(i, num_egs=10)
# Out:
# Total Motifs: 2255
# Total Questions: 199861
# Total Fragments: 2756
# Number of Motifs in each cluster:  [197, 379, 236, 265, 277, 310, 244, 347]
# Number of Questions of each type:  [11310, 25616, 34548, 29001, 17672, 21754, 29862, 30098]
# 10 examples for type 1-8:
# 	10 sample question motifs for type 0 (197 total motifs):
# 		1. ('made_*',)
# 		2. ('made_*', 'made_what')
# 		3. ('made_*', 'made_been', 'made_what')
# 		4. ('made_*', 'what>*', 'what>what')
# 		5. ('made_*', 'made_is', 'made_what')
# 		6. ('made_*', 'made_being', 'made_what')
# 		7. ('made_*', 'made_in')
# 		8. ('made_*', 'made_been')
# 		9. ('made_*', 'made_has', 'made_what')
# 		10. ('made_*', 'made_has', 'made_in')
# 	10 sample answer fragments for type 0 (365 total fragments) :
# 		1. discussed_*
# 		2. discussed_with
# 		3. discussed_have
# 		4. discussed_in
# 		5. reassure_can
# 		6. will>continue
# 		7. sent_to
# 		8. sent_*
# 		9. as>soon
# 		10. assure_however
# 	10 sample questions that were assigned type 0 (11310 total questions with this type) :
# 		1. 0.5426088359310283
# 		2. 0.5653774924974748
# 		3. 0.5678463781473096
# 		4. 0.5685297279854519
# 		5. 0.5685297279854519
# 		6. 0.5698088550857233
# 		7. 0.5711776016746211
# 		8. 0.5734847269082001
# 		9. 0.5739036725089497
# 		10. 0.5741987318896595
# 	10 sample question motifs for type 1 (379 total motifs):
# 		1. ('why>*',)
# 		2. ('explain_*',)
# 		3. ('explain_*', 'will>*')
# 		4. ('explain_*', 'explain_will')
# 		5. ('admit_*',)
# 		6. ('admit_*', 'will>*')
# 		7. ('why>*', 'why>does')
# 		8. ('where>*',)
# 		9. ('admit_*', 'admit_will')
# 		10. ('stop_*',)
# 	10 sample answer fragments for type 1 (583 total fragments) :
# 		1. suggest_*
# 		2. understand_does
# 		3. tell_will
# 		4. wonder_*
# 		5. is_extraordinary
# 		6. says_is
# 		7. cost_*
# 		8. talks_about
# 		9. talks_*
# 		10. hoped_have
# 	10 sample questions that were assigned type 1 (25616 total questions with this type) :
# 		1. 0.5652605505783016
# 		2. 0.5699354905631436
# 		3. 0.5715383874793077
# 		4. 0.5715383874793077
# 		5. 0.5715383874793077
# 		6. 0.5715383874793077
# 		7. 0.5715383874793077
# 		8. 0.5717836366220996
# 		9. 0.5741284824333001
# 		10. 0.5761588618270483
# 	10 sample question motifs for type 2 (236 total motifs):
# 		1. ('agree_*',)
# 		2. ('agree_*', 'agree_is')
# 		3. ('agree_*', 'agree_be', 'does>*')
# 		4. ('agree_*', 'agree_be')
# 		5. ('agree_*', 'agree_also')
# 		6. ('does>*',)
# 		7. ('agree_*', 'agree_does', 'although>*')
# 		8. ('agree_*', 'although>*')
# 		9. ('agree_*', 'agree_are')
# 		10. ('agree_*', 'agree_have')
# 	10 sample answer fragments for type 2 (280 total fragments) :
# 		1. agree_is
# 		2. agree_will
# 		3. agree_completely
# 		4. agree_certainly
# 		5. agree_does
# 		6. agree_also
# 		7. agree_strongly
# 		8. agree_*
# 		9. agree_absolutely
# 		10. agree_with
# 	10 sample questions that were assigned type 2 (34548 total questions with this type) :
# 		1. 0.3678743356832655
# 		2. 0.37312800508406596
# 		3. 0.37351324529785324
# 		4. 0.37351324529785324
# 		5. 0.37351324529785324
# 		6. 0.37621991902055296
# 		7. 0.37621991902055296
# 		8. 0.37621991902055296
# 		9. 0.37621991902055296
# 		10. 0.37621991902055296
# 	10 sample question motifs for type 3 (265 total motifs):
# 		1. ('accept_*',)
# 		2. ('accept_*', 'accept_does')
# 		3. ('accept_*', 'accept_does', 'accept_is')
# 		4. ('accept_*', 'accept_is')
# 		5. ('accept_*', 'accept_does', 'accept_not')
# 		6. ('accept_*', 'accept_is', 'does>*')
# 		7. ('accept_*', 'will>*')
# 		8. ('accept_*', 'accept_not')
# 		9. ('accept_*', 'accept_will')
# 		10. ('does>*', 'does>not')
# 	10 sample answer fragments for type 3 (283 total fragments) :
# 		1. no_*
# 		2. surely>*
# 		3. no>*
# 		4. nor>*
# 		5. believe_not
# 		6. believe_do
# 		7. believe_is
# 		8. believe_has
# 		9. believe_*
# 		10. believe_in
# 	10 sample questions that were assigned type 3 (29001 total questions with this type) :
# 		1. 0.4597910294424609
# 		2. 0.4625999615653855
# 		3. 0.46558143392265033
# 		4. 0.468029505986045
# 		5. 0.4705411199861235
# 		6. 0.4716048073307789
# 		7. 0.4716048073307789
# 		8. 0.4716048073307789
# 		9. 0.4716048073307789
# 		10. 0.47237241879119873
# 	10 sample question motifs for type 4 (277 total motifs):
# 		1. ('what>*',)
# 		2. ('what>*', 'what>are')
# 		3. ('doing_*', 'doing_are')
# 		4. ('what>*', 'what>what')
# 		5. ('doing_*', 'what>*')
# 		6. ('doing_*',)
# 		7. ('update_*', 'update_on')
# 		8. ('taking_*', 'taking_are')
# 		9. ('update_*', 'update_on', 'update_will')
# 		10. ('update_*', 'update_on', 'will>*')
# 	10 sample answer fragments for type 4 (436 total fragments) :
# 		1. supporting_*
# 		2. raises_*
# 		3. supporting_are
# 		4. as>well
# 		5. makes_*
# 		6. am_pleased
# 		7. is_raise
# 		8. continue_work
# 		9. including_*
# 		10. taking_in
# 	10 sample questions that were assigned type 4 (17672 total questions with this type) :
# 		1. 0.43678470137527614
# 		2. 0.43678470137527614
# 		3. 0.44301331481387063
# 		4. 0.44301331481387063
# 		5. 0.44301331481387063
# 		6. 0.44301331481387063
# 		7. 0.44301331481387063
# 		8. 0.44301331481387063
# 		9. 0.44301331481387063
# 		10. 0.44301331481387063
# 	10 sample question motifs for type 5 (310 total motifs):
# 		1. ('be_*', 'be_will')
# 		2. ('expect_*', 'expect_does')
# 		3. ('confirm_*', 'confirm_be')
# 		4. ('expect_*',)
# 		5. ('be_*', 'be_in', 'be_will')
# 		6. ('give_*',)
# 		7. ('say_*',)
# 		8. ('be_*', 'be_will', 'will>*')
# 		9. ('give_*', 'give_now')
# 		10. ('happen_*', 'happen_what')
# 	10 sample answer fragments for type 5 (398 total fragments) :
# 		1. once>*
# 		2. expect_do
# 		3. will>have
# 		4. confirm_not
# 		5. have_wait
# 		6. arise_*
# 		7. remain_will
# 		8. until>*
# 		9. give_will
# 		10. tell_must
# 	10 sample questions that were assigned type 5 (21754 total questions with this type) :
# 		1. 0.44994537690711167
# 		2. 0.44994537690711167
# 		3. 0.44994537690711167
# 		4. 0.44994537690711167
# 		5. 0.44994537690711167
# 		6. 0.44994537690711167
# 		7. 0.44994537690711167
# 		8. 0.44994537690711167
# 		9. 0.44994537690711167
# 		10. 0.44994537690711167
# 	10 sample question motifs for type 6 (244 total motifs):
# 		1. ('in>*',)
# 		2. ('be_*', 'be_not', 'would>*')
# 		3. ('in>*', 'learned_*')
# 		4. ('be_*', 'be_not', 'be_would')
# 		5. ('be_*', 'be_not')
# 		6. ('be_*', 'would>*')
# 		7. ('learned_*', 'learned_in')
# 		8. ('be_*', 'be_in', 'be_not')
# 		9. ('in>*', 'learned_*', 'learned_in')
# 		10. ('is_*', 'is_aware')
# 	10 sample answer fragments for type 6 (163 total fragments) :
# 		1. must>*
# 		2. emphasise_*
# 		3. note_*
# 		4. consider_must
# 		5. no>doubt
# 		6. note_said
# 		7. whether>*
# 		8. consider_be
# 		9. reach_*
# 		10. note_says
# 	10 sample questions that were assigned type 6 (29862 total questions with this type) :
# 		1. 0.5165039592160948
# 		2. 0.5165039592160948
# 		3. 0.5165039592160948
# 		4. 0.5165039592160948
# 		5. 0.5165039592160948
# 		6. 0.5165039592160948
# 		7. 0.5165039592160948
# 		8. 0.5165039592160948
# 		9. 0.5165039592160948
# 		10. 0.5165039592160948
# 	10 sample question motifs for type 7 (347 total motifs):
# 		1. ('will>*',)
# 		2. ('consider_*',)
# 		3. ('consider_*', 'consider_will')
# 		4. ('consider_*', 'will>*')
# 		5. ('ask_*',)
# 		6. ('raise_*', 'raise_will')
# 		7. ('ensure_*', 'will>*')
# 		8. ('consider>*', 'consider_*')
# 		9. ('undertake_*',)
# 		10. ('consider_*', 'consider_making', 'will>*')
# 	10 sample answer fragments for type 7 (248 total fragments) :
# 		1. am_sure
# 		2. am_*
# 		3. consider_certainly
# 		4. am_know
# 		5. am_aware
# 		6. discuss_*
# 		7. get_back
# 		8. get>*
# 		9. am_interested
# 		10. am_always
# 	10 sample questions that were assigned type 7 (30098 total questions with this type) :
# 		1. 0.5522792808307794
# 		2. 0.5706237101207966
# 		3. 0.5706237101207966
# 		4. 0.5706237101207966
# 		5. 0.5706237101207966
# 		6. 0.5706237101207966
# 		7. 0.5706237101207966
# 		8. 0.5706237101207966
# 		9. 0.5706237101207966
# 		10. 0.5706237101207966
